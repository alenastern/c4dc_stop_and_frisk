# %%
import pandas as pd
import numpy as np

# %%
fd_17 = pd.read_csv('data/sf_data_10_17_field.csv')
fd_18 = pd.read_csv('data/sf_data_18_field.csv')
incident = pd.read_csv('data/combined_sf_data.csv')

# %%
fd_17.head()
# Out:
#      date      time  ampm    Year                Block address District  \
# 0  1/2/12  15:27:50   NaN  2012.0  1400 BLOCK OF DOWNING ST NE       5D
# 1  1/5/12  19:04:30   NaN  2012.0   1700 BLOCK OF MONROE ST NE       5D
# 2  1/5/12  19:29:12   NaN  2012.0   1700 BLOCK OF MONROE ST NE       5D
# 3  1/7/12   3:12:06   NaN  2012.0     Multiple/Unknown Address      NaN
# 4  1/7/12   3:12:06   NaN  2012.0     Multiple/Unknown Address      NaN
#
#      PSA FIELD CONTACT TYPE     REASON FOR STOP Data Type   Race  \
# 0  505.0    Pedestrian Stop  Community Policing    Person  Black
# 1  504.0    Pedestrian Stop    Call For Service    Person  Black
# 2  504.0    Pedestrian Stop    Call For Service    Person  Black
# 3    NaN    Pedestrian Stop      Truancy/curfew    Person  Black
# 4    NaN    Pedestrian Stop      Truancy/curfew    Person  Black
#
#                 Ethnicity     Sex       Age
# 0  Not Hispanic Or Latino    Male        34
# 1  Not Hispanic Or Latino    Male  Juvenile
# ...

# %%
fd_18.head()
# Out:
#      date     time ampm  Year                         Block address District  \
# 0  1/1/17  3:58:41   AM  2017   1200 BLOCK OF CONNECTICUT AVENUE NW       2D
# 1  1/1/17  4:28:24   PM  2017          1500 BLOCK OF HALF STREET SW       1D
# 2  1/1/17  5:45:32   PM  2017  1400 BLOCK OF PENNSYLVANIA AVENUE SE       1D
# 3  1/1/17  5:45:32   PM  2017  1400 BLOCK OF PENNSYLVANIA AVENUE SE       1D
# 4  1/1/17  8:30:40   PM  2017           700 BLOCK OF 13TH STREET SE       1D
#
#      PSA FIELD CONTACT TYPE      REASON FOR STOP Data Type   Race  \
# 0  208.0       Vehicle Stop     Moving Violation    Person  White
# 1  105.0    Pedestrian Stop  Suspicious Activity    Person  Black
# 2  108.0       Vehicle Stop     Moving Violation    Person  Black
# 3  108.0       Vehicle Stop     Moving Violation    Person  Black
# 4  106.0    Pedestrian Stop  Suspicious Activity    Person  Black
#
#                 Ethnicity     Sex Age
# 0  Not Hispanic Or Latino    Male  28
# ...

# %%
incident.head()
# Out:
#            type        date      time ampm  month  day  year  hour  min  sec  \
# 0  Stop & Frisk  2017-01-01  12:26:22   AM      1    1  2017     0   26   22
# 1  Stop & Frisk  2017-01-01  12:26:22   AM      1    1  2017     0   26   22
# 2  Stop & Frisk  2017-01-01  12:26:22   AM      1    1  2017     0   26   22
# 3  Stop & Frisk  2017-01-01  12:26:22   AM      1    1  2017     0   26   22
# 4  Stop & Frisk  2017-01-01  12:26:22   AM      1    1  2017     0   26   22
#
#        ...      time_six_hour block_num      block_name low_range high_range  \
# 0      ...            0:00:00    1200.0  18TH STREET NW    3444.0     3499.0
# 1      ...            0:00:00    1200.0  18TH STREET NW    1300.0     1399.0
# 2      ...            0:00:00    1200.0  18TH STREET NW    1000.0     1099.0
# 3      ...            0:00:00    1200.0  18TH STREET NW     800.0      899.0
# 4      ...            0:00:00    1200.0  18TH STREET NW    3400.0     3443.0
#
# ...

# %%
tract = incident.groupby('CensusTract').count()

# %%
tract.rename(index= str, columns={'type': 'count'}, inplace = True)
tract.reset_index(inplace=True)

# %%
tract = tract[['CensusTract', 'count']]

# %%
tract['pct'] = tract['count']/sum(tract['count'])
# Out:
# /Users/alenastern/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
